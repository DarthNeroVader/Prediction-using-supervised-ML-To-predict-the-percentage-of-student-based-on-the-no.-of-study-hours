# %% [markdown]
# The Sparks foundation
# Name: Neeraj Kumar Juvvaladinne
# Task1:Prediction using supervised ML To predict the percentage of an student based on the no. of study hours

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv("/content/student_info.csv")
data
# Out:
#      study_hours  student_marks
# 0           6.83          78.50
# 1           6.56          76.74
# 2            NaN          78.68
# 3           5.67          71.82
# 4           8.67          84.19
# ..           ...            ...
# 195         7.53          81.67
# 196         8.56          84.68
# 197         8.94          86.75
# 198         6.60          78.05
# 199         8.35          83.50
#
# [200 rows x 2 columns]

# %%
data.isna()
data=data.dropna()

# %%
data.plot(x='study_hours',y='student_marks',style='1')
plt.title('hours vs percentage')
plt.xlabel('hours studied')
plt.ylabel('percentage scored')
plt.show()

# %%
data.plot.pie(x='study_hours',y='student_marks')
# Out:
# <Axes: ylabel='student_marks'>

# %%
X= data.iloc[:,:-1].values
Y=data.iloc[:,1].values
#training and testing
from sklearn.model_selection import train_test_split
X_train, X_test ,Y_train, Y_test=train_test_split(X,Y,test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,Y_train)
print(X_test)
print("prediction of score")
Y_pred=regressor.predict(X_test)
print(Y_pred)
# Out:
# [[5.63]
#  [7.9 ]
#  [7.1 ]
#  [5.4 ]
#  [5.39]
#  [8.71]
#  [5.07]
#  [6.38]
#  [5.11]
#  [7.67]
#  [5.19]
#  [6.67]
#  [6.33]
#  [5.38]
#  [5.39]
#  [8.05]
#  [7.14]
#  [6.35]
#  [7.01]
#  [8.95]
#  [5.39]
#  [5.79]
#  [8.6 ]
#  [8.2 ]
#  [5.45]
#  [8.93]
#  [7.95]
#  [5.19]
#  [7.26]
#  [5.01]
#  [5.85]
#  [7.86]
#  [5.07]
#  [7.88]
#  [7.55]
#  [6.66]
#  [8.66]
#  [5.02]
#  [7.87]]
# prediction of score
# [72.66609379 81.45824996 78.35969272 71.77525859 71.73652662 84.59553917
#  70.49710373 75.57099121 70.65203159 80.56741476 70.96188731 76.69421821
#  75.37733138 71.69779466 71.73652662 82.03922945 78.51462059 75.45479531
#  78.01110503 85.52510634 71.73652662 73.28580524 84.16948755 82.62020893
#  71.96891841 85.44764241 81.65190979 70.96188731 78.97940417 70.26471193
#  73.51819703 81.3033221  70.49710373 81.38078603 80.10263117 76.65548624
#  84.40187934 70.3034439  81.34205407]

# %%
df=pd.DataFrame({'actual':Y_test,'predicted':Y_pred})
df
# Out:
#     actual  predicted
# 0    72.87  72.666094
# 1    80.76  81.458250
# 2    76.76  78.359693
# 3    70.34  71.775259
# 4    71.11  71.736527
# 5    85.98  84.595539
# 6    70.79  70.497104
# 7    77.01  75.570991
# 8    72.08  70.652032
# 9    80.58  80.567415
# 10   70.66  70.961887
# 11   76.99  76.694218
# 12   74.49  75.377331
# 13   71.94  71.697795
# 14   73.02  71.736527
# 15   79.63  82.039229
# 16   77.65  78.514621
# 17   76.19  75.454795
# 18   77.46  78.011105
# 19   85.15  85.525106
# 20   70.90  71.736527
# 21   73.64  73.285805
# 22   84.58  84.169488
# 23   82.10  82.620209
# 24   70.06  71.968918
# 25   86.65  85.447642
# 26   80.86  81.651910
# 27   71.18  70.961887
# 28   78.17  78.979404
# 29   70.11  70.264712
# 30   75.02  73.518197
# 31   80.72  81.303322
# 32   69.27  70.497104
# 33   83.23  81.380786
# 34   81.18  80.102631
# 35   76.63  76.655486
# 36   86.99  84.401879
# 37   70.58  70.303444
# 38   82.04  81.342054

# %%
hours=[[9.25]]
pred=regressor.predict(hours)
print(pred)
# Out:
# [86.68706531]

# %%
from sklearn import metrics
print('Mean absolute error',
      metrics.mean_absolute_error(Y_test,Y_pred))
# Out:
# Mean absolute error 0.874366072505091
